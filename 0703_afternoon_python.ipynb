# %%
a = input()
b = int(a) if 1<int(a) < 10 else 0
# Out:
# 5

# %%
a = input()
try:
    b=int(a) # 숫자일 경우만 else 실행, 아닐 경우 except 실행
except :
    print('숫자 입력해')
else :
    print('잘 입력하셨어요')
finally :
    print('무조건 실행') #bold 초록색은 키워드,
# Out:
# 5
# 잘 입력하셨어요
# 무조건 실행

# %%
while b != -1 :
    a = input()
    try :
        b = int(a)
            
    except :
        print('다시 입력해주세요')
    else: 
        for i in range(1,10) : 
            print(i * b)
        b = -1

# %%
import keyword

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ab9f2cb3ccea> in <module>()
# ----> 1 dir(kwlist)
#
# NameError: name 'kwlist' is not defined

# %%
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'kwlist',
#  'main']

# %%
help (keyword)
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "graminit.c")
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree after building the interpreter and run:
#
#         ./python Lib/keyword.py
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
#         x.__contains__(y) <==> y in x.
#
# DATA
#     __all__ = ['iskeyword', 'kwlist']
#     kwlist = ['False', 'None', 'True', 'and', 'as', 'assert', 'break', 'cl...
#
# FILE
#     c:\users\seongsong park\anaconda3\lib\keyword.py

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 33

# %%
a = input()
try:
    b=int(a) # 숫자일 경우만 else 실행, 아닐 경우 except 실행
except :
    print('숫자 입력해')
else :
    print('잘 입력하셨어요')
finally :
    print('무조건 실행') #bold 초록색은 키워드,
# Out:
# 5
# 잘 입력하셨어요
# 무조건 실행

# %%
import sys

# %%
type(sys.stderr)
# Out:
# ipykernel.iostream.OutStream

# %%
sys.stderr.encoding
# Out:
# 'UTF-8'

# %%
3/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-f6cc6d14333b> in <module>()
# ----> 1 3/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #### Try, except , raise :
# try :
#     ..
#
#
# - except(ZeroDivisionError, OverflowError): #이런 방식으로 두개 같이 처리 가능
# - 아무것도 쓰지 않을 경우는 모든 에러 처리 하는거
# - except여러개 쓸 경우 각각의 에러에 따라 다르게 처리해주는거
# - numpy as np와 같이 as를 사용해서 error의 이름을 정해주는것
# - raise를 사용하면 에러를 직접 만들 수 있음

# %%
dir(Exception)
# Out:
# ['__cause__',
#  '__class__',
#  '__context__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__suppress_context__',
#  '__traceback__',
#  'args',
#  'with_traceback']

# %%
type(Exception)
# Out:
# type

# %%
help(Exception)
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(...)
#  |      helper for pickle
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
# ...

# %% [markdown]
# #### Error
#
# - Exception : runtime error ==> 이경우가 더 찾기 힘듦 : Base Exception, Exception이 존재.: 이 경우 실행이 중단되지 않지만, 원하는 결과가 나오지 않음
# - Error : 구문 자체의 에러임 : 에러가 나올 경우 중간에 실행이 중단됨.

# %%
import numpy
import numpy as np

# %%
np.__name__
# Out:
# 'numpy'

# %%
a = 10
if a > 10 :
    print('a')
else:
    raise Exception # 이 exception으로 switch case 함수를 만들 수 있음
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-652aa3fe02ca> in <module>()
#       3     print('a')
#       4 else:
# ----> 5     raise Exception # 이 exception으로 switch case 함수를 만들 수 있음
#
# Exception:

# %%
a = 10
try :
    if a>10 :
        print('a')
    else :
        raise Exception('aaa') # exception 괄호 열고 넣어주는게 exception의 이름이 됨, 즉 exception을 세부화 시킬 수 있게 되는 것 
except :
    print(0)
# Out:
# 0

# %%
def a(a):
    try:
        print('0')
        return 0
    finally :
        print('1')
        return 1

# %%
a(3) # try except에는 return 두개 넣어도 됨
# Out:
# 0
# 1
# 1

# %%
# 중간에 값 확인하려고 print하지 말고 assert를 사용 하세요

# %%
b =11
assert b==10 # 만약에 원하는 코드와 값이 다르다면 에러가 뜸. 

#이때 값 변화까지 알고싶다면 ?  d
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-9b4c871cefe4> in <module>()
#       1 b =11
# ----> 2 assert b==10 # 만약에 원하는 코드와 값이 다르다면 에러가 뜸.
#       3
#       4 #이때 값 변화까지 알고싶다면 ?
#
# AssertionError:

# %% [markdown]
# ####  함수
# - assert같은거 쓰게 되면서 다들 함수를 열씨미 쓰기 시작했음
# - first class function : 함수가 값처럼 사용할 수 있는 경우
# - high order function : 함수의 인자로 함수가 들어갈 수 있고, 함수의 결과값으로 함수가 나올 수 있음

# %%
a =[1,2,3]

# %%
sum(a)
# Out:
# 6

# %%
문근영 = sum
문근영(a)
# Out:
# 6

# %%
a=[str.upper,str.lower]
a[0]('abc') #함수가 값이 할 수 있는 애들이 다되는거 : first class fuction이니까
# Out:
# 'ABC'

# %%
def a (func) : 
    print(func('abc'))

# %%
a(str.upper) # 함수를 인자로 넣은거
# Out:
# ABC

# %%
b=a(str.title)
# Out:
# Abc

# %%
b('abc')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-c338e2a1bbbd> in <module>()
# ----> 1 b('abc')
#
# TypeError: 'NoneType' object is not callable

# %%
import keyword

# %%
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'kwlist',
#  'main']

# %%
keyword.kwlist

#false는 값 0, type 은 bool, numeric,
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
True == None
# Out:
# False

# %%
False ==None
# Out:
# False

# %%
if None:
    print('a')
else :
    print('b')
# Out:
# b

# %%
a = None

if a is not None : 
    print('a')
else :
    print('b')
# Out:
# b

# %%
a = lambda x : x+1 # x를 받으면 입력이 x, return값이 x+1

# %%
a(1)
# Out:
# 2

# %%
 b = lambda : 3

# %%
b()
# Out:
# 3

# %%
c = lambda x,y : x+y+3

# %%
c(2,3)
# Out:
# 8

# %%
def add_x_y () : 
    """문근영은 예쁘다""" #이렇게 넣으면 shift tab 넣으면 docstring으로 참조할수 있음
    pass
    return 0  #이 때 return None하면 아무것도 반환안하는 거임

# %%
dir(add_x_y()) #이때 call이 있으면
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
1+add_x_y()
# Out:
# 1
